# %%
from keras.models import Sequential
# Out:
# Using TensorFlow backend.

# %%
from keras.layers import Dense, Activation, LSTM

# %%
from keras.optimizers import RMSprop

# %%
from keras.utils.data_utils import get_file

# %%
import numpy as np

# %%
import random

# %%
import sys

# %%
path = './kazeno_matasaburo.txt'

# %%
bindata = open(path, "rb").read()

# %%
text = bindata.decode("shift_jis")

# %%
print('Size of text: ', len(text))
# Out:
# Size of text:  32608

# %%
chars = sorted(list(set(text)))

# %%
print('Total chars:', len(chars))
# Out:
# Total chars: 783

# %%
char_indices = dict((c, i) for i, c in enumerate(chars))

# %%
indices_char = dict((i, c) for i, c in enumerate(chars))

# %%
maxlen = 40

# %%
step = 3

# %%
sentences = []
next_chars = []

# %%
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])

# %%
print('Number of sentences: ', len(sentences))
# Out:
# Number of sentences:  10856

# %%
#テキストのベクト化

# %%
X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)

# %%
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

# %%
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1

# %%
#モデルを定義する

# %%
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))

# %%
model.add(Dense(len(chars)))

# %%
model.add(Activation('softmax'))

# %%
optimizer = RMSprop(lr=0.01)

# %%
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
for iteration in range(1, 60):
    print()
    print('-' * 50)
    print('繰り返し回数: ', iteration)
    model.fit(X, y, batch_size=128, epochs=1)

start_index = random.randint(0, len(text) - maxlen - 1)

for diversity in [0.2, 0.5, 1.0, 1.2]:
    print()
    print('------diversity', diversity)
    
    generated = ''
    sentence = text[start_index: start_index + maxlen]
    generated += sentence
    print('---- Seedを生成しました: ' + sentence + '"')
    sys.stdout.write(generated)
    
    for i in range(400):
        x = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(sentence):
            x[0, t, char_indices[char]] = 1.
            
        preds = model.predict(x, verbose=9)[0]
        next_index = sample(preds, diversity)
        next_char = indices_char[next_index]
        
        generated += next_char
        sentence = sentence[1:] + next_char
        
        sys.stdout.write(next_char)
        sys.stdout.flush()
        
    print()
# Out:
# --------------------------------------------------
# 繰り返し回数:  1
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0532
#
# --------------------------------------------------
# 繰り返し回数:  2
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0496
#
# --------------------------------------------------
# 繰り返し回数:  3
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0477
#
# --------------------------------------------------
# 繰り返し回数:  4
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0513
#
# --------------------------------------------------
# 繰り返し回数:  5
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0503
#
# --------------------------------------------------
# 繰り返し回数:  6
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0529
#
# --------------------------------------------------
# 繰り返し回数:  7
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0513
#
# --------------------------------------------------
# 繰り返し回数:  8
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0551
#
# --------------------------------------------------
# 繰り返し回数:  9
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0481
#
# --------------------------------------------------
# 繰り返し回数:  10
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0554
#
# --------------------------------------------------
# 繰り返し回数:  11
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0451
#
# --------------------------------------------------
# 繰り返し回数:  12
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0534
#
# --------------------------------------------------
# 繰り返し回数:  13
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0501
#
# --------------------------------------------------
# 繰り返し回数:  14
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0535
#
# --------------------------------------------------
# 繰り返し回数:  15
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0471
#
# --------------------------------------------------
# 繰り返し回数:  16
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0452
#
# --------------------------------------------------
# 繰り返し回数:  17
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0392
#
# --------------------------------------------------
# 繰り返し回数:  18
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0415
#
# --------------------------------------------------
# 繰り返し回数:  19
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0440
#
# --------------------------------------------------
# 繰り返し回数:  20
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0421
#
# --------------------------------------------------
# 繰り返し回数:  21
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0427
#
# --------------------------------------------------
# 繰り返し回数:  22
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0443
#
# --------------------------------------------------
# 繰り返し回数:  23
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0446
#
# --------------------------------------------------
# 繰り返し回数:  24
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0424
#
# --------------------------------------------------
# 繰り返し回数:  25
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0512
#
# --------------------------------------------------
# 繰り返し回数:  26
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0428
#
# --------------------------------------------------
# 繰り返し回数:  27
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0390
#
# --------------------------------------------------
# 繰り返し回数:  28
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0427
#
# --------------------------------------------------
# 繰り返し回数:  29
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0433
#
# --------------------------------------------------
# 繰り返し回数:  30
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0432
#
# --------------------------------------------------
# 繰り返し回数:  31
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0406
#
# --------------------------------------------------
# 繰り返し回数:  32
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0396
#
# --------------------------------------------------
# 繰り返し回数:  33
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0399
#
# --------------------------------------------------
# 繰り返し回数:  34
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0393
#
# --------------------------------------------------
# 繰り返し回数:  35
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0313
#
# --------------------------------------------------
# 繰り返し回数:  36
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0357
#
# --------------------------------------------------
# 繰り返し回数:  37
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0356
#
# --------------------------------------------------
# 繰り返し回数:  38
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0382
#
# --------------------------------------------------
# 繰り返し回数:  39
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0352
#
# --------------------------------------------------
# 繰り返し回数:  40
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0322
#
# --------------------------------------------------
# 繰り返し回数:  41
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0345
#
# --------------------------------------------------
# 繰り返し回数:  42
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0404
#
# --------------------------------------------------
# 繰り返し回数:  43
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0379
#
# --------------------------------------------------
# 繰り返し回数:  44
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0345
#
# --------------------------------------------------
# 繰り返し回数:  45
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0352
#
# --------------------------------------------------
# 繰り返し回数:  46
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0407
#
# --------------------------------------------------
# 繰り返し回数:  47
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0329
#
# --------------------------------------------------
# 繰り返し回数:  48
# Epoch 1/1
# 10856/10856 [==============================] - 21s - loss: 0.0350
#
# --------------------------------------------------
# 繰り返し回数:  49
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0365
#
# --------------------------------------------------
# 繰り返し回数:  50
# Epoch 1/1
# 10856/10856 [==============================] - 21s - loss: 0.0320
#
# --------------------------------------------------
# 繰り返し回数:  51
# Epoch 1/1
# 10856/10856 [==============================] - 21s - loss: 0.0296
#
# --------------------------------------------------
# 繰り返し回数:  52
# Epoch 1/1
# 10856/10856 [==============================] - 21s - loss: 0.0347
#
# --------------------------------------------------
# 繰り返し回数:  53
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0328
#
# --------------------------------------------------
# 繰り返し回数:  54
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0280
#
# --------------------------------------------------
# 繰り返し回数:  55
# Epoch 1/1
# 10856/10856 [==============================] - 21s - loss: 0.0347
#
# --------------------------------------------------
# 繰り返し回数:  56
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0324
#
# --------------------------------------------------
# 繰り返し回数:  57
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0347
#
# --------------------------------------------------
# 繰り返し回数:  58
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0339
#
# --------------------------------------------------
# 繰り返し回数:  59
# Epoch 1/1
# 10856/10856 [==============================] - 20s - loss: 0.0280
#
# ------diversity 0.2
# ---- Seedを生成しました: いました。
# 　そこはたぶんは、野馬の集まり場所であったでしょう。霧の中に丸い広"
# いました。
# 　そこはたぶんは、野馬の集まり場所であったでしょう。霧の中に丸い広いが言いました。みんなは前まにと見ていました。そのうしろから、
# 「おつ　　そのうしまって、んだんだか、
# 「なん、このうのなくらみんなはならと集まってしまいました。と思っていました。
# 「おうも。あ、」
# 「なん、この前をぐなぐ。」と言いました。
# 　ひはやっと一郎の木を見ながら手をあいました。
# 　はこまがなんのこうの山の上ほうではすこうでもまってくいっていました。
# 　嘉助はやっと起わかにないた。」ががやっと言いました。
# 「うわか、それから。」三郎が言いました。ました。
# 「おいらないがら、だっとよろ。」みんないが言いました。
# 「す。
# 「なんだ、あ、西あ、あいあい。」
# 「又三郎って来るのか。」
# 「あありない、ない。」
# 「ぼくさんはやって来たぞ。」三郎が言いました。
# 「おおいないがないな。」と言いながら本のほうはこんまた行きました。
# 　すると一郎は、どっこまわこってここ
#
# ------diversity 0.5
# ---- Seedを生成しました: いました。
# 　そこはたぶんは、野馬の集まり場所であったでしょう。霧の中に丸い広"
# いました。
# 　そこはたぶんは、野馬の集まり場所であったでしょう。霧の中に丸い広いかわけできました。
# 　空い少し大きな楢、「はいっやって来たぞ。」一郎が言いました。
# 「おうち。一郎、
# 「おまあまた。」
# 「あ、あの木はすかすた。」
# 「あありな、、またす、三郎だみんながら、やっと白」
# 「待っていたのだった。」
# 　みんなはで嘉助は言いました。
# 「す。あ、はやはやはこうでは雨がしいでした。
# 　すると嘉助は半はやっと来たんだいます。一郎はにいましたが、十つもからました。
# 「あるおうい。」
# 「又三郎って来るのかないが。」と言いながら本のほうできませんでした。
# 　三郎は、こっちを見っと鳴が、て下のほうへ行きました。
# 　ていたう「な子は、そらはここえ、をもう何して郎っていたのです。
# 　みんなは、らこしたように立っていました。そしてまるでろかったのです。するは三郎がす。
# 「たらさん、います。」
# 「なんなそりあ一郎のほんだぞ。」と嘉助は小さなみんとじって一
#
# ------diversity 1.0
# ---- Seedを生成しました: いました。
# 　そこはたぶんは、野馬の集まり場所であったでしょう。霧の中に丸い広"
# いました。
# 　そこはたぶんは、野馬の集まり場所であったでしょう。霧の中に丸い広いが言いました。みんなは前ます。
# 「そらめま行くち。」三郎はおそうに高く叫びました。
# 　みんなはわら、だまって耕助はまるでもっと起《はぼっと言いながら本ので、風がくつもて棒からいようようした。そして、その下をまわいて」りました。三郎はちいんとよろに飛をうってまたみんなにしい思いました。
# 　四年はたがたべたように向こうの四べつとこっていたももいり高
# っています。その人はどておらいちそした。
# 　すると嘉助はやっと鳴らいました。
# 「おうちれ。いさあ、。」
# 「又三郎っていまばあ取さら。」
# 「変ょ、どがするやとい石して。」三郎がきました。
# 　先生はちゃんと一列のとといってしまいます。すると三郎が、
# 「吉ああり、いませ、らっちについてて、ように叫びながらうんだんでした。としてもこんしてもみんな考はまた一っていました。そして顔を見ていました。
# 　空はうちれを前に、「おうしい。」と言い
#
# ------diversity 1.2
# ---- Seedを生成しました: いました。
# 　そこはたぶんは、野馬の集まり場所であったでしょう。霧の中に丸い広"
# いました。
# 　そこはたぶんは、野馬の集まり場所であったでしょう。霧の中に丸い広いが顔いろを見ていました。
# 　吉もたくさんはだんだりってまたさあみんな突ら水を出してするのだったる馬みんけをにないやしました。
# 　（ああ、がい、そのひはだかかったのだっちへひららも持っていました。そなにた二年言葉木はまるでいって来たさい。」
# 「りか、それからどや。」
# 　耕助がらんだかました。そして先生に行きました。みんなはばた子たました。
# 　すると嘉助はよろくここをらは、だたったのだらいち
# 　みんなは、とな西きをとはておらしいんでした。そして三郎もぐりにぐばみな。そのにかい字かりしました。
# 　（ああ、ぐいないな、さあ、あのおじしろで」
# 「ああり、又三郎《おとうささあおました。叫んなりがわしたばらをから、くるききました。
# 「春らるひだい。」それから言って来ました。みんなれいちその前ま集め出しょうにする草でした。
# 「あおおいいな。」と嘉助はとそれに
# 「ころが、それからあ行
